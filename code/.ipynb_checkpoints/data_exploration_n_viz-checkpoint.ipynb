# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
dfsj = pd.read_csv('../data/processed/covid19-JHU/covid19-JHU.csv')
dfsj['Date'] = pd.to_datetime(dfsj['Date'])

dfp = pd.read_csv('../data/raw/population/populations.csv')
dfp.index = dfp.Country.values
dfp.drop(['Country'], axis=1, inplace=True)
dfp.index.rename('Country', inplace=True)
dfp.head()
# Out:
#            Population
# Country
# China      1439323776
# India      1380004385
# US          331002651
# Indonesia   273523615
# Pakistan    220892340

# %%
dfsj.reset_index(level=0, inplace=True)
dfsj.head()
# Out:
#    index      Country  Confirmed  Deaths  Recovered       Date  Population  \
# 0      0  Afghanistan        1.0     0.0        0.0 2020-02-24  38928346.0
# 1      1  Afghanistan        1.0     0.0        0.0 2020-02-25  38928346.0
# 2      2  Afghanistan        1.0     0.0        0.0 2020-02-26  38928346.0
# 3      3  Afghanistan        1.0     0.0        0.0 2020-02-27  38928346.0
# 4      4  Afghanistan        1.0     0.0        0.0 2020-02-28  38928346.0
#
#    PercPopConfirmed  PercPopDeaths
# 0          0.000003            0.0
# 1          0.000003            0.0
# 2          0.000003            0.0
# 3          0.000003            0.0
# 4          0.000003            0.0

# %%
dfsj['Country'][0]
# Out:
# 'Afghanistan'

# %%
limit = 2500

# %%
dfsjm = pd.DataFrame(dfsj.groupby(['Country'])['Confirmed'].max()).sort_values('Confirmed', ascending=False)
plotlist = dfsjm[dfsjm['Confirmed'] > limit ].index.tolist()
#plotlist.pop(plotlist.index('China'))
plotlist
# Out:
# ['US',
#  'Italy',
#  'Spain',
#  'Germany',
#  'China',
#  'France',
#  'Iran',
#  'UK',
#  'Switzerland',
#  'Turkey',
#  'Belgium',
#  'Netherlands',
#  'Canada',
#  'Austria',
#  'South Korea',
#  'Portugal',
#  'Brazil',
#  'Israel',
#  'Sweden',
#  'Norway',
#  'Australia',
#  'Czech Republic',
#  'Ireland',
#  'Denmark',
#  'Russia',
#  'Chile',
#  'Ecuador',
#  'Malaysia',
#  'Poland',
#  'Romania',
#  'Philippines',
#  'India']

# %%
# OR DO THIS
plotlist = ['China', 'Italy',  'Iran', 'Spain', 'Germany', 'US', 'France', 'South Korea', 'Switzerland', 'UK']

# %%
dfplot = dfsj[dfsj.Country.isin(plotlist)]
dfplot
# Out:
#       index Country  Confirmed  Deaths  Recovered       Date    Population  \
# 1045   1045   China      547.0    17.0       28.0 2020-01-22  1.439324e+09
# 1046   1046   China      639.0    18.0       30.0 2020-01-23  1.439324e+09
# 1047   1047   China      916.0    26.0       36.0 2020-01-24  1.439324e+09
# 1048   1048   China     1399.0    42.0       39.0 2020-01-25  1.439324e+09
# 1049   1049   China     2062.0    56.0       49.0 2020-01-26  1.439324e+09
# ...     ...     ...        ...     ...        ...        ...           ...
# 5356   5356      US   140886.0  2467.0     2665.0 2020-03-29  3.310027e+08
# 5357   5357      US   161807.0  2978.0     5644.0 2020-03-30  3.310027e+08
# 5358   5358      US   188172.0  3873.0     7024.0 2020-03-31  3.310027e+08
# 5359   5359      US   213372.0  4757.0     8474.0 2020-04-01  3.310027e+08
# 5360   5360      US   243453.0  5926.0     9001.0 2020-04-02  3.310027e+08
#
#       PercPopConfirmed  PercPopDeaths
# 1045          0.000038       0.000001
# 1046          0.000044       0.000001
# 1047          0.000064       0.000002
# 1048          0.000097       0.000003
# 1049          0.000143       0.000004
# ...                ...            ...
# 5356          0.042563       0.000745
# 5357          0.048884       0.000900
# 5358          0.056849       0.001170
# 5359          0.064462       0.001437
# 5360          0.073550       0.001790
#
# [624 rows x 9 columns]

# %% [markdown]
# ## country comparison graphs

# %%
grpd = dfplot.groupby(['Country'])
for name, data in grpd:
    plt.plot('Date', 'Confirmed', data=data.sort_values('Date'), label = name)
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Cases')
plt.title('Cumulative Confirmed # of Cases by Date\n')
plt.legend(loc='upper left')

# %%
grpd = dfplot.groupby(['Country'])
for name, data in grpd:
    plt.plot('Date', 'Deaths', data=data.sort_values('Date'), label = name)
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths')
plt.title('Cumulative Deaths by Date\n')
plt.legend(loc='upper left')

# %%
grpd = dfplot.groupby(['Country'])
for name, data in grpd:
    print(name)
    plt.plot('Date', 'PercPopConfirmed', data=data.sort_values('Date'), label = name)
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('% of Population wtih Cases')
plt.title('Cumulative Confirmed % of Population with Cases by Date\n')
plt.legend(loc='upper left')
# Out:
# China
# France
# Germany
# Iran
# Italy
# South Korea
# Spain
# Switzerland
# UK
# US

# %%
grpd = dfplot.groupby(['Country'])
for name, data in grpd:
    plt.plot('Date', 'PercPopDeaths', data=data.sort_values('Date'), label = name)
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('% of Population wtih Deaths')
plt.title('Cumulative Confirmed % of Population with Deaths by Date\n')
plt.legend(loc='upper left')

# %%
start =1
dfplots = dfplot[dfplot['Deaths'] > start]
grpd = dfplots.groupby(['Country'])

# %%
#plt.xticks(rotation=70)
for name, data in grpd:
    plt.plot(data.PercPopConfirmed.values, label = name)
plt.ylabel('% of Population wtih Cases')
plt.xlabel('Days Since Reaching ' + str(start) + ' Cases')
plt.title('Cumulative Confirmed % of Population with Cases\nWith Alligned Start at ' + str(start) + ' Cases')
plt.legend()

# %%
#plt.xticks(rotation=70)
for name, data in grpd:
    plt.plot(data.PercPopDeaths.values, label = name)
plt.ylabel('% of Population wtih Deaths')
plt.xlabel('Days Since Reaching ' + str(start) + ' Cases')
plt.title('Cumulative Confirmed % of Population with Deaths\nWith Alligned Start at ' + str(start) + ' Cases')
plt.legend()

# %%
#plt.xticks(rotation=70)
for name, data in grpd:
    plt.plot(data.Confirmed.values, label = name)
plt.ylabel('# of Cases')
plt.xlabel('Days Since Reaching ' + str(start) + ' Cases')
plt.title('Cumulative Confirmed Cases\nWith Alligned Start at ' + str(start) + ' Cases')
plt.legend()

# %%
#plt.xticks(rotation=70)
for name, data in grpd:
    plt.plot(data.Deaths.values, label = name)
plt.ylabel('# of Deaths')
plt.xlabel('Days Since Reaching ' + str(start) + ' Deaths')
plt.title('Cummulative Confirmed Deaths\nWith Alligned Start at ' + str(start) + ' Cases')
plt.legend()

# %% [markdown]
# # bring in CDC flu deaths

# %%
mort = pd.read_csv('../data/raw/cdcfluview/mortality.csv')

# %%
mort.head()
# Out:
#    seasonid  baseline  threshold  percent_pni  percent_complete  \
# 0        59     0.053      0.057        0.052               1.0
# 1        59     0.054      0.057        0.053               1.0
# 2        59     0.055      0.058        0.055               1.0
# 3        59     0.056      0.059        0.056               1.0
# 4        59     0.057      0.060        0.054               1.0
#
#    number_influenza  number_pneumonia  all_deaths  total_pni  weeknumber  \
# 0                16              2702       52444       2718          40
# 1                16              2769       52858       2785          41
# 2                18              2976       54120       2994          42
# 3                30              2984       53906       3014          43
# 4                31              2906       53971       2937          44
#
#   geo_description age_label  week_start    week_end  year_week_num  mmwrid  \
# 0        National       All  2019-09-29  2019-10-05             40    3014
# 1        National       All  2019-10-06  2019-10-12             41    3015
# 2        National       All  2019-10-13  2019-10-19             42    3016
# 3        National       All  2019-10-20  2019-10-26             43    3017
# 4        National       All  2019-10-27  2019-11-02             44    3018
#
#   coverage_area region_name        callout
# 0      national    national  Normal levels
# 1      national    national  Normal levels
# 2      national    national  Normal levels
# 3      national    national  Normal levels
# 4      national    national  Normal levels

# %%
mort = mort[['total_pni', 'week_start', 'week_end']]
mort['week_start'] = pd.to_datetime(mort['week_start'])
mort['week_end'] = pd.to_datetime(mort['week_end'])
mort.sort_values('week_end', ascending=True, inplace=True)
mort
# Out:
#      total_pni week_start   week_end
# 285       3143 2013-09-29 2013-10-05
# 286       3147 2013-10-06 2013-10-12
# 287       3227 2013-10-13 2013-10-19
# 288       3162 2013-10-20 2013-10-26
# 289       3283 2013-10-27 2013-11-02
# ..         ...        ...        ...
# 19        3906 2020-02-09 2020-02-15
# 20        3775 2020-02-16 2020-02-22
# 21        3787 2020-02-23 2020-02-29
# 22        3576 2020-03-01 2020-03-07
# 23        2796 2020-03-08 2020-03-14
#
# [337 rows x 3 columns]

# %%
plt.plot('week_end', 'total_pni', data=mort, label = 'US Flu')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# Deaths per Week')
plt.title('US Historical Weekly Deaths for the Common Flu')
plt.legend(loc='upper left')

# %%
pni = []
dates = []
for index, row in mort.iterrows():
    i=0
    m = row['total_pni'] / 7
    d = row['week_start'].date()
    while d < row['week_end'].date():
        d = row['week_start'].date() + pd.DateOffset(i)
        dates.append(d)
        pni.append(m)
#         print(d)
        i+=1

# %%
cols = {'flu_deaths':pni,'Date':dates}
flu = pd.DataFrame(cols)

# %%
flu['month_day'] = flu['Date'].astype(str).str.slice(5, 10, 1)

# %%
uspop = dfp[dfp.index=='US'].values

# %%
x = 1000000*flu['flu_deaths'].values/uspop
x[0]
# Out:
# array([1.3564846 , 1.3564846 , 1.3564846 , ..., 1.20672318, 1.20672318,
#        1.20672318])

# %%
flu['flu_deaths_per1m'] = x[0]

# %%
flu.head()
# Out:
#    flu_deaths       Date month_day  flu_deaths_per1m
# 0       449.0 2013-09-29     09-29          1.356485
# 1       449.0 2013-09-30     09-30          1.356485
# 2       449.0 2013-10-01     10-01          1.356485
# 3       449.0 2013-10-02     10-02          1.356485
# 4       449.0 2013-10-03     10-03          1.356485

# %%
flu[flu['month_day']=='01-01']
# Out:
#       flu_deaths       Date month_day  flu_deaths_per1m
# 94    691.428571 2014-01-01     01-01          2.088891
# 459   864.000000 2015-01-01     01-01          2.610251
# 824   564.000000 2016-01-01     01-01          1.703914
# 1190  692.428571 2017-01-01     01-01          2.091912
# 1555  903.000000 2018-01-01     01-01          2.728075
# 1920  589.714286 2019-01-01     01-01          1.781600
# 2285  625.571429 2020-01-01     01-01          1.889929

# %%
fluSeason = flu[flu.Date < pd.Timestamp(2019,9,1)]

# %%
fluSeason['month'] = fluSeason.Date.dt.month
# Out:
# /usr/local/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fluSeason = fluSeason.groupby(['month_day']).mean()

# %%
fluSeason.head()
# Out:
#            flu_deaths  flu_deaths_per1m  month
# month_day
# 01-01      717.428571          2.167441      1
# 01-02      717.428571          2.167441      1
# 01-03      725.166667          2.190818      1
# 01-04      740.095238          2.235919      1
# 01-05      754.523810          2.279510      1

# %%
fluSeason['Date'] = fluSeason.index

# %%
fluSeason['Date'][fluSeason.month >= 9] = '2019-' + fluSeason.Date
fluSeason['Date'][fluSeason.month < 9] = '2020-' + fluSeason.Date
fluSeason['Date'] = pd.to_datetime(fluSeason['Date'])
fluSeason.sort_values('Date', inplace=True)
# Out:
# /usr/local/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.plot('Date', 'flu_deaths', data=fluSeason, label = 'US Flu 6-year Avg')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.title('Daily Deaths')
plt.legend(loc='lower left')

# %% [markdown]
# ### US COVID

# %%
# mort.sort_values('total_pni', inplace=True)
x = 100000*mort['total_pni'].values/uspop
mort['total_pni_per100k'] = x[0]
mort.head()
# Out:
#      total_pni week_start   week_end  total_pni_per100k
# 285       3143 2013-09-29 2013-10-05           0.949539
# 286       3147 2013-10-06 2013-10-12           0.950748
# 287       3227 2013-10-13 2013-10-19           0.974917
# 288       3162 2013-10-20 2013-10-26           0.955279
# 289       3283 2013-10-27 2013-11-02           0.991835

# %%
mort.tail()
# Out:
#     total_pni week_start   week_end  total_pni_per100k
# 19       3906 2020-02-09 2020-02-15           1.180051
# 20       3775 2020-02-16 2020-02-22           1.140474
# 21       3787 2020-02-23 2020-02-29           1.144100
# 22       3576 2020-03-01 2020-03-07           1.080354
# 23       2796 2020-03-08 2020-03-14           0.844706

# %%
uscovid = dfsj[dfsj.Country=='US'].sort_values('Date', ascending=True)

# %%
covid = []     
i=0
for index, row in uscovid.iterrows():
#     print(uscovid.iloc[i]['Deaths'])
    if i==0:
        d = row['Deaths'] 
    else:
        d = row['Deaths'] - uscovid.iloc[i-1]['Deaths']
    i+=1
#     print(d)
    covid.append(d)
uscovid['dailyDeaths'] = covid

# %%
x = 1000000*uscovid['dailyDeaths'].values/uspop

# %%
uscovid['dailyDeaths_per1m'] = x[0]

# %% [markdown]
# ### Italy COVID

# %%
italycovid = dfsj[dfsj.Country=='Italy'].sort_values('Date', ascending=True)
italypop = dfp[dfp.index=='Italy'].values

# %%
covid = []     
i=0
for index, row in italycovid.iterrows():
#     print(uscovid.iloc[i]['Deaths'])
    if i==0:
        d = row['Deaths'] 
    else:
        d = row['Deaths'] - italycovid.iloc[i-1]['Deaths']
    i+=1
#     print(d)
    covid.append(d)
italycovid['dailyDeaths'] = covid

# %%
x = 1000000*italycovid['dailyDeaths'].values/italypop

# %%
italycovid['dailyDeaths_per1m'] = x[0]
italycovid.head()
# Out:
#       index Country  Confirmed  Deaths  Recovered       Date  Population  \
# 2528   2528   Italy        2.0     0.0        0.0 2020-01-31  60461826.0
# 2529   2529   Italy        2.0     0.0        0.0 2020-02-01  60461826.0
# 2530   2530   Italy        2.0     0.0        0.0 2020-02-02  60461826.0
# 2531   2531   Italy        2.0     0.0        0.0 2020-02-03  60461826.0
# 2532   2532   Italy        2.0     0.0        0.0 2020-02-04  60461826.0
#
#       PercPopConfirmed  PercPopDeaths  dailyDeaths  dailyDeaths_per1m
# 2528          0.000003            0.0          0.0                0.0
# 2529          0.000003            0.0          0.0                0.0
# 2530          0.000003            0.0          0.0                0.0
# 2531          0.000003            0.0          0.0                0.0
# 2532          0.000003            0.0          0.0                0.0

# %% [markdown]
# ### South Korea COVID

# %%
skcovid = dfsj[dfsj.Country=='South Korea'].sort_values('Date', ascending=True)
skpop = dfp[dfp.index=='South Korea'].values

# %%
covid = []     
i=0
for index, row in skcovid.iterrows():
#     print(uscovid.iloc[i]['Deaths'])
    if i==0:
        d = row['Deaths'] 
    else:
        d = row['Deaths'] - skcovid.iloc[i-1]['Deaths']
    i+=1
#     print(d)
    covid.append(d)
skcovid['dailyDeaths'] = covid

# %%
x = 1000000*skcovid['dailyDeaths'].values/skpop

# %%
skcovid['dailyDeaths_per1m'] = x[0]
skcovid.head()
# Out:
#       index      Country  Confirmed  Deaths  Recovered       Date  Population  \
# 4596   4596  South Korea        1.0     0.0        0.0 2020-01-22  51269185.0
# 4597   4597  South Korea        1.0     0.0        0.0 2020-01-23  51269185.0
# 4598   4598  South Korea        2.0     0.0        0.0 2020-01-24  51269185.0
# 4599   4599  South Korea        2.0     0.0        0.0 2020-01-25  51269185.0
# 4600   4600  South Korea        3.0     0.0        0.0 2020-01-26  51269185.0
#
#       PercPopConfirmed  PercPopDeaths  dailyDeaths  dailyDeaths_per1m
# 4596          0.000002            0.0          0.0                0.0
# 4597          0.000002            0.0          0.0                0.0
# 4598          0.000004            0.0          0.0                0.0
# 4599          0.000004            0.0          0.0                0.0
# 4600          0.000006            0.0          0.0                0.0

# %% [markdown]
# ### China COVID

# %%
chinacovid = dfsj[dfsj.Country=='China'].sort_values('Date', ascending=True)
chinapop = dfp[dfp.index=='China'].values

# %%
chinacovid[chinacovid.Deaths == 0]
# Out:
#       index Country  Confirmed  Deaths  Recovered       Date    Population  \
# 1095   1095   China        0.0     0.0        0.0 2020-03-11  1.439324e+09
# 1097   1097   China        0.0     0.0        0.0 2020-03-12  1.439324e+09
#
#       PercPopConfirmed  PercPopDeaths
# 1095               0.0            0.0
# 1097               0.0            0.0

# %%
chinacovid.drop(chinacovid[chinacovid.Deaths == 0].index, inplace=True)

# %%
dfsj.dtypes
# Out:
# index                        int64
# Country                     object
# Confirmed                  float64
# Deaths                     float64
# Recovered                  float64
# Date                datetime64[ns]
# Population                 float64
# PercPopConfirmed           float64
# PercPopDeaths              float64
# dtype: object

# %%
chinacovid[(chinacovid.Date <= pd.Timestamp(2020,3,13)) & \
           (chinacovid.Date >= pd.Timestamp(2020,3,10))]
# Out:
#       index Country  Confirmed  Deaths  Recovered       Date    Population  \
# 1093   1093   China    80757.0  3136.0    60106.0 2020-03-10  1.439324e+09
# 1094   1094   China    80921.0  3161.0    61644.0 2020-03-11  1.439324e+09
# 1096   1096   China    80932.0  3172.0    62901.0 2020-03-12  1.439324e+09
# 1098   1098   China    80945.0  3180.0    64196.0 2020-03-13  1.439324e+09
#
#       PercPopConfirmed  PercPopDeaths
# 1093          0.005611       0.000218
# 1094          0.005622       0.000220
# 1096          0.005623       0.000220
# 1098          0.005624       0.000221

# %%
covid = []     
i=0
for index, row in chinacovid.iterrows():
    if i==0:
        d = row['Deaths'] 
    else:
        d = row['Deaths'] - chinacovid.iloc[i-1]['Deaths']
    i+=1
#     print(d)
    covid.append(d)
chinacovid['dailyDeaths'] = covid

# %%
x = 1000000*chinacovid['dailyDeaths'].values/chinapop

# %%
chinacovid['dailyDeaths_per1m'] = x[0]

# %% [markdown]
# ## compare covid19 to the regular flu

# %%
uscovid['Week'] = pd.to_datetime(uscovid['Date']) - pd.to_timedelta(7, unit='d')

#get sums of sun to sat
#the week date will be the sat before the count starts
uscovidwk = uscovid.groupby(['Country', pd.Grouper(key='Week', freq='W-SAT')])['dailyDeaths'] \
.sum().reset_index().sort_values('Week')

uscovidwk.rename(columns={'dailyDeaths': 'weeklyDeaths'}, inplace=True)

#add one day so the week starts on Sun
uscovidwk['Week'] = uscovidwk['Week'] + pd.to_timedelta(1, unit='d')

#drop tail if in a partial week
last_sunday = least_recent_date = uscovidwk['Week'].max()
# print(last_sunday)
uscovidwk.drop(uscovidwk[uscovidwk.Week >= pd.Timestamp(last_sunday)].index, inplace=True)
uscovidwk
# Out:
#   Country       Week  weeklyDeaths
# 0      US 2020-01-19           0.0
# 1      US 2020-01-26           0.0
# 2      US 2020-02-02           0.0
# 3      US 2020-02-09           0.0
# 4      US 2020-02-16           0.0
# 5      US 2020-02-23           1.0
# 6      US 2020-03-01          16.0
# 7      US 2020-03-08          37.0
# 8      US 2020-03-15         253.0
# 9      US 2020-03-22        1719.0

# %%
plt.plot('Week', 'weeklyDeaths', data=uscovidwk, label = 'US COVID-19')
plt.plot('week_end', 'total_pni', data=mort, label = 'US Flu')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# Deaths')
plt.title('Weekly Deaths')
plt.legend(loc='lower left')

# %%
# grpd = dfplot.groupby(['Country'])
# for name, data in grpd:
plt.plot('Date', 'dailyDeaths', data=uscovid, label = 'US COVID-19')
plt.plot('Date', 'flu_deaths', data=flu, label = 'US Flu')
# plt.plot('Date', 'dailyDeaths', data=italycovid, label = 'Italy COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths')
plt.title('Daily Deaths')
plt.legend(loc='lower left')

# %%
# grpd = dfplot.groupby(['Country'])
# for name, data in grpd:
plt.plot('Date', 'dailyDeaths_per1m', data=uscovid, label = 'US COVID-19')
plt.plot('Date', 'flu_deaths_per1m', data=flu, label = 'US Flu')
# plt.plot('Date', 'dailyDeaths_per1m', data=italycovid, label = 'Italy COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 1M People')
plt.title('Daily Deaths per 1M People')
plt.legend(loc='lower left')

# %% [markdown]
# ### I think this next graph offers the best assessment of the situation
# ### We can't trust # of cases as a measure of the severity as testing details vary around the world
# ### Deaths is probably the most reliable metric and thus the best measure of severity
# ### Overlaying COVID-19 deaths with expected flu deaths and flu deaths to date for this season gives a clear picture of the impact of COVID-19
# ### Getting expected flu deaths and up to date current season flu deaths for non-US countries is challenging

# %%
plt.plot('Date', 'flu_deaths', data=fluSeason, label = 'US Flu 6 Yr Avg')
plt.plot('Date', 'flu_deaths', data=flu[flu.Date >= pd.Timestamp(2019, 9, 1)], label = '2019-20 US Flu')
plt.plot('Date', 'dailyDeaths', data=uscovid, label = 'US COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths')
plt.title('Daily Deaths')
plt.legend(loc='lower right')

# %%
plt.plot('Date', 'flu_deaths_per1m', data=fluSeason, label = 'US Flu 6 Yr Avg')
plt.plot('Date', 'flu_deaths_per1m', data=flu[flu.Date >= pd.Timestamp(2019, 9, 1)], label = '2019-20 US Flu')
plt.plot('Date', 'dailyDeaths_per1m', data=uscovid, label = 'US COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 1M People')
plt.title('Daily Deaths per 1M People')
plt.legend(loc='lower right')

# %%
plt.plot('Date', 'flu_deaths_per1m', data=fluSeason, label = 'US Flu 6 Yr Avg')
# plt.plot('Date', 'flu_deaths_per1m', data=flu[flu.Date >= pd.Timestamp(2019, 9, 1)], label = '2019-20 US Flu')
plt.plot('Date', 'dailyDeaths_per1m', data=uscovid, label = 'US COVID-19')
plt.plot('Date', 'dailyDeaths_per1m', data=italycovid, label = 'Italy COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 1M People')
plt.title('Daily Deaths per 1M People')
plt.legend(loc='upper right')

# %%
plt.plot('Date', 'flu_deaths_per1m', data=fluSeason, label = 'US Flu 6 Yr Avg')
# plt.plot('Date', 'flu_deaths_per1m', data=flu[flu.Date >= pd.Timestamp(2019, 9, 1)], label = '2019-20 US Flu')
plt.plot('Date', 'dailyDeaths_per1m', data=uscovid, label = 'US COVID-19')
plt.plot('Date', 'dailyDeaths_per1m', data=chinacovid, label = 'China COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 1M People')
plt.title('Daily Deaths per 1M People')
plt.legend(loc='lower left')

# %%
plt.plot('Date', 'flu_deaths_per1m', data=fluSeason, label = 'US Flu 6 Yr Avg')
# plt.plot('Date', 'flu_deaths_per1m', data=flu[flu.Date >= pd.Timestamp(2019, 9, 1)], label = '2019-20 US Flu')
plt.plot('Date', 'dailyDeaths_per1m', data=uscovid, label = 'US COVID-19')
plt.plot('Date', 'dailyDeaths_per1m', data=skcovid, label = 'South Korea\nCOVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 1M People')
plt.title('Daily Deaths per 1M People')
plt.legend(loc='lower left')

# %% [markdown]
# ## Italy COVID-19 deaths
# ## Weekly
# ## per 100,000
# ## overlayed with academic study
# Investigating the impact of influenza on excess mortality in all ages in Italy during recent seasons (2013/14–2016/17 seasons)
# https://www.sciencedirect.com/science/article/pii/S1201971219303285

# %%
italycovid['Week'] = pd.to_datetime(italycovid['Date']) - pd.to_timedelta(7, unit='d')

#get sums of sun to sat
#the week date will be the sat before the count starts
italycovidwk = italycovid.groupby(['Country', pd.Grouper(key='Week', freq='W-SAT')])['dailyDeaths'] \
.sum().reset_index().sort_values('Week')

italycovidwk.rename(columns={'dailyDeaths': 'weeklyDeaths'}, inplace=True)

#add one day so the week starts on Sun
italycovidwk['Week'] = italycovidwk['Week'] + pd.to_timedelta(1, unit='d')

#drop tail if in a partial week
last_sunday = least_recent_date = italycovidwk['Week'].max()
# print(last_sunday)
italycovidwk.drop(italycovidwk[italycovidwk.Week >= pd.Timestamp(last_sunday)].index, inplace=True)
italycovidwk
# Out:
#   Country       Week  weeklyDeaths
# 0   Italy 2020-01-26           0.0
# 1   Italy 2020-02-02           0.0
# 2   Italy 2020-02-09           0.0
# 3   Italy 2020-02-16           2.0
# 4   Italy 2020-02-23          27.0
# 5   Italy 2020-03-01         204.0
# 6   Italy 2020-03-08        1208.0
# 7   Italy 2020-03-15        3384.0
# 8   Italy 2020-03-22        5198.0

# %%
x = 100000*italycovidwk['weeklyDeaths'].values/italypop

# %%
italycovidwk['weeklyDeaths_per100k'] = x[0]

# %%
# logic check
italycovidwk
# Out:
#   Country       Week  weeklyDeaths  weeklyDeaths_per100k
# 0   Italy 2020-01-26           0.0              0.000000
# 1   Italy 2020-02-02           0.0              0.000000
# 2   Italy 2020-02-09           0.0              0.000000
# 3   Italy 2020-02-16           2.0              0.003308
# 4   Italy 2020-02-23          27.0              0.044656
# 5   Italy 2020-03-01         204.0              0.337403
# 6   Italy 2020-03-08        1208.0              1.997955
# 7   Italy 2020-03-15        3384.0              5.596920
# 8   Italy 2020-03-22        5198.0              8.597160

# %%
#logic check
italycovid.tail(14)
# Out:
#       index Country  Confirmed   Deaths  Recovered       Date  Population  \
# 2577   2577   Italy    47021.0   4032.0     4440.0 2020-03-20  60461826.0
# 2578   2578   Italy    53578.0   4825.0     6072.0 2020-03-21  60461826.0
# 2579   2579   Italy    59138.0   5476.0     7024.0 2020-03-22  60461826.0
# 2580   2580   Italy    63927.0   6077.0     7432.0 2020-03-23  60461826.0
# 2581   2581   Italy    69176.0   6820.0     8326.0 2020-03-24  60461826.0
# 2582   2582   Italy    74386.0   7503.0     9362.0 2020-03-25  60461826.0
# 2583   2583   Italy    80589.0   8215.0    10361.0 2020-03-26  60461826.0
# 2584   2584   Italy    86498.0   9134.0    10950.0 2020-03-27  60461826.0
# 2585   2585   Italy    92472.0  10023.0    12384.0 2020-03-28  60461826.0
# 2586   2586   Italy    97689.0  10779.0    13030.0 2020-03-29  60461826.0
# 2587   2587   Italy   101739.0  11591.0    14620.0 2020-03-30  60461826.0
# 2588   2588   Italy   105792.0  12428.0    15729.0 2020-03-31  60461826.0
# 2589   2589   Italy   110574.0  13155.0    16847.0 2020-04-01  60461826.0
# 2590   2590   Italy   115242.0  13915.0    18278.0 2020-04-02  60461826.0
#
#       PercPopConfirmed  PercPopDeaths  dailyDeaths  dailyDeaths_per1m  \
# 2577          0.077770       0.006669        627.0          10.370180
# 2578          0.088615       0.007980        793.0          13.115714
# 2579          0.097810       0.009057        651.0          10.767124
# 2580          0.105731       0.010051        601.0           9.940156
# 2581          0.114413       0.011280        743.0          12.288746
# 2582          0.123030       0.012409        683.0          11.296384
# 2583          0.133289       0.013587        712.0          11.776025
# 2584          0.143062       0.015107        919.0          15.199673
# 2585          0.152943       0.016577        889.0          14.703492
# 2586          0.161571       0.017828        756.0          12.503757
# 2587          0.168270       0.019171        812.0          13.429962
# 2588          0.174973       0.020555        837.0          13.843446
# 2589          0.182882       0.021758        727.0          12.024116
# 2590          0.190603       0.023015        760.0          12.569915
#
#            Week
# 2577 2020-03-13
# 2578 2020-03-14
# 2579 2020-03-15
# 2580 2020-03-16
# 2581 2020-03-17
# 2582 2020-03-18
# 2583 2020-03-19
# 2584 2020-03-20
# 2585 2020-03-21
# 2586 2020-03-22
# 2587 2020-03-23
# 2588 2020-03-24
# 2589 2020-03-25
# 2590 2020-03-26

# %%
plt.plot('Date', 'dailyDeaths_per1m', data=italycovid, label = 'Italy COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 1M People')
plt.title('Daily Deaths per 1M People')
plt.legend(loc='upper left')

# %%
plt.plot('Week', 'weeklyDeaths_per100k', data=italycovidwk, label = 'Italy COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 100,000 People')
plt.title('Weekly Deaths per 100,000 People')
plt.legend(loc='upper left')

# %% [markdown]
# ### From academic study

# %%
italy_baseline = pd.read_csv('../data/raw/italy/italy_flu_baseline.csv')

# %%
italy_baseline['Date'] = pd.to_datetime(italy_baseline['date'])

# %%
# us baseline minimum. the italy study didn't calculate a minimum.
italy_baseline.weeklyDeaths_per100k = italy_baseline.weeklyDeaths_per100k + 0.78

# %%
# convert to daily per 1M
italy_baseline['dailyDeaths_per1m'] = italy_baseline.weeklyDeaths_per100k * 10 / 7

# %%
italy_baseline['month_day'] = italy_baseline['date'].astype(str).str.slice(5, 10, 1)

# %%
italy_baseline_avg = italy_baseline.groupby(['month_day']).mean()

# %%
# us baseline minimum. the italy study didn't calculate a minimum.
italy_baseline_avg.weeklyDeaths_per100k = italy_baseline_avg.weeklyDeaths_per100k + 0.78

# %%
italy_baseline
# Out:
#      date  weeklyDeaths_per100k       Date  dailyDeaths_per1m month_day
# 0  9/1/13                  0.78 2013-09-01           1.114286         3
# 1  1/1/14                  2.78 2014-01-01           3.971429         4
# 2  9/1/14                  0.78 2014-09-01           1.114286         4
# 3  1/1/15                  5.78 2015-01-01           8.257143         5
# 4  9/1/15                  0.78 2015-09-01           1.114286         5
# 5  1/1/16                  4.78 2016-01-01           6.828571         6
# 6  9/1/16                  0.78 2016-09-01           1.114286         6
# 7  1/1/17                  7.78 2017-01-01          11.114286         7
# 8  9/1/17                  0.78 2017-09-01           1.114286         7

# %%
italy_baseline_avg
# Out:
#            weeklyDeaths_per100k  dailyDeaths_per1m
# month_day
# 3                          1.56           1.114286
# 4                          2.56           2.542857
# 5                          4.06           4.685714
# 6                          3.56           3.971429
# 7                          5.06           6.114286

# %%
#hand code the data since it's small
data = [['2019-09-01', 0.78], ['2020-01-01', 5.28], ['2020-09-01', 0.78]] 
  
# Create the pandas DataFrame 
italy_baseline_avg = pd.DataFrame(data, columns = ['Date', 'weeklyDeaths_per100k'])
italy_baseline_avg['Date'] = pd.to_datetime(italy_baseline_avg['Date'])
# convert to daily per 1M
italy_baseline_avg['dailyDeaths_per1m'] = italy_baseline_avg.weeklyDeaths_per100k * 10 / 7
italy_baseline_avg
# Out:
#         Date  weeklyDeaths_per100k  dailyDeaths_per1m
# 0 2019-09-01                  0.78           1.114286
# 1 2020-01-01                  5.28           7.542857
# 2 2020-09-01                  0.78           1.114286

# %%
plt.plot('Date', 'weeklyDeaths_per100k', data=italy_baseline, label = 'Italy Historical Flu')
plt.plot('Week', 'weeklyDeaths_per100k', data=italycovidwk, label = 'Italy COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 100,000 People')
plt.title('Weekly Deaths per 100,000 People')
plt.legend(loc='upper left')

# %%
plt.plot('Date', 'dailyDeaths_per1m', data=italy_baseline, label = 'Italy Historical Flu')
plt.plot('Week', 'dailyDeaths_per1m', data=italycovid, label = 'Italy COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 1M People')
plt.title('Daily Deaths per 1M People')
plt.legend(loc='upper left')

# %%
plt.plot('Date', 'weeklyDeaths_per100k', data=italy_baseline_avg, label = 'Italy 4 yr Avg Flu')
plt.plot('Week', 'weeklyDeaths_per100k', data=italycovidwk, label = 'Italy COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 100,000 People')
plt.title('Weekly Deaths per 100,000 People')
plt.legend(loc='lower right')

# %%
plt.plot('Date', 'dailyDeaths_per1m', data=italy_baseline_avg, label = 'Italy 4 yr Avg Flu')
plt.plot('Date', 'dailyDeaths_per1m', data=italycovid, label = 'Italy COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 1M People')
plt.title('Daily Deaths per 1M People')
plt.legend(loc='lower right')

# %%
#replot this so the graphs of interest are together at the bottom of the notebook
plt.plot('Date', 'flu_deaths', data=fluSeason, label = 'US Flu 6 Yr Avg')
plt.plot('Date', 'flu_deaths', data=flu[flu.Date >= pd.Timestamp(2019, 9, 1)], label = '2019-20 US Flu')
plt.plot('Date', 'dailyDeaths', data=uscovid, label = 'US COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths')
plt.title('Daily Deaths')
plt.legend(loc='lower right')

# %%
plt.plot('Date', 'flu_deaths_per1m', data=fluSeason, label = 'US Flu 6 Yr Avg')
# plt.plot('Date', 'flu_deaths_per1m', data=flu[flu.Date >= pd.Timestamp(2019, 9, 1)], label = '2019-20 US Flu')
plt.plot('Date', 'dailyDeaths_per1m', data=uscovid, label = 'US COVID-19')
plt.plot('Date', 'dailyDeaths_per1m', data=italy_baseline_avg, label = 'Italy Flu 4 Yr Avg (est.)')
plt.plot('Date', 'dailyDeaths_per1m', data=italycovid, label = 'Italy COVID-19')
# plt.plot('Date', 'dailyDeaths_per1m', data=chinacovid, label = 'China COVID-19')
plt.xticks(rotation=70)
plt.xlabel('Date')
plt.ylabel('# of Deaths per 1M People')
plt.title('Daily Deaths per 1M People')
plt.legend(loc='upper left')
