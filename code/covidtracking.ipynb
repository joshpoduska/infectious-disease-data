# %% [markdown]
# ## Save data to the project and do some exploration if desired

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
usin = 'https://covidtracking.com/api/us/daily.csv'
statesin = 'https://covidtracking.com/api/v1/states/current.csv'

usout = '../data/raw/covidtracking/us_historical.csv'
statesout = '../data/raw/covidtracking/states_historical.csv'

# %% [markdown]
# #### not going to merge in the numbers from the current day, but you can do so if you like

# %%
pd.read_csv('https://covidtracking.com/api/v1/us/current.csv')
# Out:
#    positive  negative  pending  hospitalizedCurrently  hospitalizedCumulative  \
# 0    959056   4482023     4445                  55030                   95810
#
#    inIcuCurrently  inIcuCumulative  onVentilatorCurrently  \
# 0           14831             2571                   5121
#
#    onVentilatorCumulative  recovered  \
# 0                     227      91001
#
#                                        hash lastModified  death  hospitalized  \
# 0  35ca7aa3088495c5ae3ccedabe2981a9bc5caabc    4/27/2020  49164         95810
#
#      total  totalTestResults   posNeg  \
# 0  5445524           5441079  5441079
#
#                                                notes
# 0  NOTE: "total", "posNeg", "hospitalized" will b...

# %%
pd.read_csv('https://covidtracking.com/api/v1/states/current.csv').head(2)
# Out:
#   state  positive  positiveScore  negativeScore  negativeRegularScore  \
# 0    AK       341            1.0            1.0                   1.0
# 1    AL      6270            1.0            1.0                   0.0
#
#    commercialScore grade  score  \
# 0              1.0     A    4.0
# 1              1.0     B    3.0
#
#                                                notes dataQualityGrade  ...  \
# 0  Please stop using the "total" field. Use "tota...                B  ...
# 1  Please stop using the "total" field. Use "tota...                B  ...
#
#    checkTimeEt  death  hospitalized  total  totalTestResults  posNeg  fips  \
# 0   4/26 15:55      9           NaN  16177             16177   16177     2
# 1   4/26 16:31    216         845.0  73551             73551   73551     1
#
#            dateModified           dateChecked  \
# 0  2020-04-26T18:15:00Z  2020-04-26T19:55:00Z
# 1  2020-04-26T04:00:00Z  2020-04-26T20:31:00Z
#
#                                        hash
# 0  92a3ca0e1d34bbc59c7fb9ece7bf7168ef148117
# 1  08cbccff1086811889f45c9b3ff358ebb03544e2
#
# [2 rows x 30 columns]

# %% [markdown]
# #### get historical numbers

# %%
df = pd.read_csv(usin)
dfs = pd.read_csv(statesin)

# %%
df.to_csv(usout)
dfs.to_csv(statesout)

# %% [markdown]
# #### brief exploration

# %%
df.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200426      56    959056  4482023.0   4445.0                55030.0
# 1  20200425      56    931698  4252937.0   5315.0                56312.0
# 2  20200424      56    890816  3995535.0   4396.0                56118.0
# 3  20200423      56    859318  3800932.0   4258.0                57879.0
# 4  20200422      56    827963  3641232.0   4191.0                58173.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                 95810.0         14831.0           2571.0
# 1                 94743.0         15020.0           2516.0
# 2                 93107.0         15078.0           2468.0
# 3                 91108.0         15163.0           2428.0
# 4                 85543.0         15341.0           2370.0
#
#    onVentilatorCurrently  ...    death  hospitalized    total  \
# 0                 5121.0  ...  49164.0       95810.0  5445524
# 1                 5266.0  ...  47980.0       94743.0  5189950
# 2                 5187.0  ...  45786.0       93107.0  4890747
# 3                 5464.0  ...  44014.0       91108.0  4664508
# 4                 5474.0  ...  42128.0       85543.0  4473386
#
#   totalTestResults   posNeg  deathIncrease  hospitalizedIncrease  \
# 0          5441079  5441079         1184.0                1067.0
# 1          5184635  5184635         2194.0                1636.0
# 2          4886351  4886351         1772.0                1999.0
# 3          4660250  4660250         1886.0                5565.0
# 4          4469195  4469195         2133.0                1251.0
#
#    negativeIncrease  positiveIncrease  totalTestResultsIncrease
# 0          229086.0           27358.0                  256444.0
# 1          257402.0           40882.0                  298284.0
# 2          194603.0           31498.0                  226101.0
# 3          159700.0           31355.0                  191055.0
# 4          285950.0           27658.0                  313608.0
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#                date     states       positive      negative       pending  \
# count  9.600000e+01  96.000000      96.000000  5.500000e+01     54.000000
# mean   2.020029e+07  30.593750  170915.333333  1.288624e+06  17586.351852
# std    9.478900e+01  26.672114  282135.269411  1.369500e+06  21946.242838
# min    2.020012e+07   1.000000       1.000000  6.000000e+00    103.000000
# 25%    2.020021e+07   1.000000       2.000000  4.207850e+04   2313.000000
# 50%    2.020031e+07  51.000000    1213.000000  7.937960e+05  10397.500000
# 75%    2.020040e+07  56.000000  251292.500000  2.306149e+06  17267.000000
# max    2.020043e+07  56.000000  959056.000000  4.482023e+06  65709.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count              36.000000               37.000000        32.00000
# mean            36641.500000            48154.432432     10149.40625
# std             21494.053072            31215.033643      5266.46184
# min               112.000000             1964.000000      1299.00000
# 25%             17285.500000            18511.000000      4710.75000
# 50%             44734.000000            48917.000000     13130.50000
# 75%             56166.500000            77955.000000     14798.75000
# max             59420.000000            95810.000000     15341.00000
#
#        inIcuCumulative  onVentilatorCurrently  ...         death  \
# count        33.000000              33.000000  ...     59.000000
# mean       1251.303030            3623.727273  ...  11612.084746
# std         873.233019            2507.697453  ...  15689.352363
# min          74.000000             167.000000  ...      4.000000
# 25%         456.000000             574.000000  ...     59.000000
# 50%        1185.000000            5187.000000  ...   2001.000000
# 75%        2096.000000            5794.000000  ...  21171.000000
# max        2571.000000            6168.000000  ...  49164.000000
#
#        hospitalized         total  totalTestResults        posNeg  \
# count     37.000000  9.600000e+01      9.600000e+01  9.600000e+01
# mean   48154.432432  9.190818e+05      9.091894e+05  9.091894e+05
# std    31215.033643  1.500773e+06      1.496967e+06  1.496967e+06
# min     1964.000000  1.000000e+00      1.000000e+00  1.000000e+00
# 25%    18511.000000  2.000000e+00      2.000000e+00  2.000000e+00
# 50%    48917.000000  5.182000e+03      4.791000e+03  4.791000e+03
# 75%    77955.000000  1.386746e+06      1.324680e+06  1.324680e+06
# max    95810.000000  5.445524e+06      5.441079e+06  5.441079e+06
#
#        deathIncrease  hospitalizedIncrease  negativeIncrease  \
# count      95.000000             95.000000         95.000000
# mean      517.515789           1008.526316      47179.189474
# std       803.277632           1497.461013      66399.954830
# min         0.000000              0.000000          0.000000
# 25%         0.000000              0.000000          0.000000
# 50%         4.000000              0.000000       1009.000000
# 75%      1127.500000           2020.500000      97026.500000
# max      2674.000000           5565.000000     285950.000000
#
#        positiveIncrease  totalTestResultsIncrease
# count         95.000000                 95.000000
# mean       10095.315789              57274.505263
# std        13213.889169              78800.709689
# min            0.000000                  0.000000
# 25%            0.000000                  0.000000
# 50%          320.000000               1329.000000
# 75%        25062.000000             122266.500000
# max        40882.000000             313608.000000
#
# [8 rows x 22 columns]
