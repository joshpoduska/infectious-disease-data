# %% [markdown]
# ## Save data to the project and do some exploration if desired

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
usin = 'https://covidtracking.com/api/us/daily.csv'
statesin = 'https://covidtracking.com/api/v1/states/current.csv'

usout = '../data/raw/covidtracking/us_historical.csv'
statesout = '../data/raw/covidtracking/states_historical.csv'

# %% [markdown]
# #### not going to merge in the numbers from the current day, but you can do so if you like

# %%
pd.read_csv('https://covidtracking.com/api/v1/us/current.csv')
# Out:
#    positive  negative  pending  hospitalizedCurrently  hospitalizedCumulative  \
# 0    861756   3822544     4432                  57902                   91461
#
#    inIcuCurrently  inIcuCumulative  onVentilatorCurrently  \
# 0           15178             2437                   5464
#
#    onVentilatorCumulative  recovered  \
# 0                     227      63642
#
#                                        hash lastModified  death  hospitalized  \
# 0  b709cf6e4c2cd20e216c929dd1c3f3ae6ef502e7    4/24/2020  44132         91461
#
#      total  totalTestResults   posNeg  \
# 0  4688732           4684300  4684300
#
#                                                notes
# 0  NOTE: "total", "posNeg", "hospitalized" will b...

# %%
pd.read_csv('https://covidtracking.com/api/v1/states/current.csv').head(2)
# Out:
#   state  positive  positiveScore  negativeScore  negativeRegularScore  \
# 0    AK       337            1.0            1.0                   1.0
# 1    AL      5832            1.0            1.0                   0.0
#
#    commercialScore grade  score  negative  pending  ...  death  hospitalized  \
# 0              1.0     A    4.0     11824      NaN  ...    9.0           NaN
# 1              1.0     B    3.0     46863      NaN  ...  197.0         768.0
#
#    total  totalTestResults  posNeg  fips          dateModified  \
# 0  12161             12161   12161     2  2020-04-23T18:00:00Z
# 1  52695             52695   52695     1  2020-04-23T04:00:00Z
#
#             dateChecked                                              notes  \
# 0  2020-04-23T19:36:00Z  Please stop using the "total" field. Use "tota...
# 1  2020-04-24T02:16:00Z  Please stop using the "total" field. Use "tota...
#
#                                        hash
# 0  51b52a9a3f56d10feb9e4a121f1d7f61d8496826
# 1  5a07c1d59e3a3083d37dbb6d05442509c9f48b94
#
# [2 rows x 29 columns]

# %% [markdown]
# #### get historical numbers

# %%
df = pd.read_csv(usin)
dfs = pd.read_csv(statesin)

# %%
df.to_csv(usout)
dfs.to_csv(statesout)

# %% [markdown]
# #### brief exploration

# %%
df.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200423      56    859318  3800932.0   4258.0                57879.0
# 1  20200422      56    827148  3639623.0   4191.0                58173.0
# 2  20200421      56    800126  3355461.0   3956.0                58468.0
# 3  20200420      56    773020  3231027.0   4037.0                55509.0
# 4  20200419      56    749486  3116661.0  11324.0                55565.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                 91108.0         15163.0           2428.0
# 1                 85465.0         15341.0           2370.0
# 2                 84292.0         15228.0           2315.0
# 3                 82879.0         14691.0           2193.0
# 4                 80881.0         14548.0           2145.0
#
#    onVentilatorCurrently  ...    death  hospitalized    total  \
# 0                 5464.0  ...  44014.0       91108.0  4664508
# 1                 5474.0  ...  42103.0       85465.0  4470962
# 2                 5514.0  ...  39995.0       84292.0  4159543
# 3                 5567.0  ...  37321.0       82879.0  4008084
# 4                 5603.0  ...  35793.0       80881.0  3877471
#
#   totalTestResults   posNeg  deathIncrease  hospitalizedIncrease  \
# 0          4660250  4660250         1911.0                5643.0
# 1          4466771  4466771         2108.0                1173.0
# 2          4155587  4155587         2674.0                1413.0
# 3          4004047  4004047         1528.0                1998.0
# 4          3866147  3866147         1654.0                2042.0
#
#    negativeIncrease  positiveIncrease  totalTestResultsIncrease
# 0          161309.0           32170.0                  193479.0
# 1          284162.0           27022.0                  311184.0
# 2          124434.0           27106.0                  151540.0
# 3          114366.0           23534.0                  137900.0
# 4          140309.0           26920.0                  167229.0
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#                date     states       positive      negative      pending  \
# count  9.300000e+01  93.000000      93.000000  5.200000e+01     51.00000
# mean   2.020029e+07  29.774194  146508.688172  1.118123e+06  18343.27451
# std    9.318743e+01  26.699670  250805.707577  1.200064e+06  22360.81633
# min    2.020012e+07   1.000000       1.000000  6.000000e+00    103.00000
# 25%    2.020021e+07   1.000000       2.000000  3.273400e+04   1966.50000
# 50%    2.020031e+07  51.000000     734.000000  6.595755e+05  11324.00000
# 75%    2.020033e+07  56.000000  190061.000000  2.062728e+06  17293.00000
# max    2.020042e+07  56.000000  859318.000000  3.800932e+06  65709.00000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count              33.000000               34.000000       29.000000
# mean            34898.000000            44058.117647     9650.068966
# std             21625.425149            29149.041814     5286.919154
# min               112.000000             1964.000000     1299.000000
# 25%             15574.000000            16825.000000     4410.000000
# 50%             40463.000000            44349.000000    12254.000000
# 75%             55565.000000            69089.000000    14667.000000
# max             59420.000000            91108.000000    15341.000000
#
#        inIcuCumulative  onVentilatorCurrently  ...         death  \
# count        30.000000              30.000000  ...     56.000000
# mean       1124.600000            3466.966667  ...   9681.392857
# std         811.514744            2580.520964  ...  13595.545968
# min          74.000000             167.000000  ...      4.000000
# 25%         419.250000             564.250000  ...     54.000000
# 50%         968.500000            4797.500000  ...   1391.000000
# 75%        1821.250000            5901.250000  ...  16940.000000
# max        2428.000000            6168.000000  ...  44014.000000
#
#        hospitalized         total  totalTestResults        posNeg  \
# count     34.000000  9.300000e+01      9.300000e+01  9.300000e+01
# mean   44058.117647  7.817549e+05      7.716957e+05  7.716957e+05
# std    29149.041814  1.309232e+06      1.304157e+06  1.304157e+06
# min     1964.000000  1.000000e+00      1.000000e+00  1.000000e+00
# 25%    16825.000000  2.000000e+00      2.000000e+00  2.000000e+00
# 50%    44349.000000  3.416000e+03      3.069000e+03  3.069000e+03
# 75%    69089.000000  1.125866e+06      1.066348e+06  1.066348e+06
# max    91108.000000  4.664508e+06      4.660250e+06  4.660250e+06
#
#        deathIncrease  hospitalizedIncrease  negativeIncrease  \
# count      92.000000             92.000000         92.000000
# mean      478.413043            990.304348      41314.478261
# std       782.175497           1519.329795      58535.375979
# min         0.000000              0.000000          0.000000
# 25%         0.000000              0.000000          0.000000
# 50%         4.000000              0.000000        685.500000
# 75%       850.750000           2045.500000      92446.250000
# max      2674.000000           5643.000000     284162.000000
#
#        positiveIncrease  totalTestResultsIncrease
# count         92.000000                 92.000000
# mean        9340.402174              50654.880435
# std        12694.197220              70541.675854
# min            0.000000                  0.000000
# 25%            0.000000                  0.000000
# 50%          250.500000                827.000000
# 75%        23769.000000             112630.750000
# max        34543.000000             311184.000000
#
# [8 rows x 22 columns]
