# %% [markdown]
# ## Save data to the project and do some exploration if desired

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
usin = 'https://covidtracking.com/api/us/daily.csv'
statesin = 'https://covidtracking.com/api/v1/states/current.csv'

usout = '../data/raw/covidtracking/us_historical.csv'
statesout = '../data/raw/covidtracking/states_historical.csv'

# %% [markdown]
# #### not going to merge in the numbers from the current day, but you can do so if you like

# %%
pd.read_csv('https://covidtracking.com/api/v1/us/current.csv')
# Out:
#    positive  negative  pending  hospitalizedCurrently  hospitalizedCumulative  \
# 0    751062   3130940     2923                  55586                   80993
#
#    inIcuCurrently  inIcuCumulative  onVentilatorCurrently  \
# 0           14582             2145                   5588
#
#    onVentilatorCumulative  recovered  \
# 0                     214      53735
#
#                                        hash lastModified  death  hospitalized  \
# 0  e9815f3af94a1fbc1282d203b66c8188e458ae5f    4/20/2020  35875         80993
#
#      total  totalTestResults   posNeg  \
# 0  3884925           3882002  3882002
#
#                                                notes
# 0  NOTE: "total", "posNeg", "hospitalized" will b...

# %%
pd.read_csv('https://covidtracking.com/api/v1/states/current.csv').head(2)
# Out:
#   state  positive  positiveScore  negativeScore  negativeRegularScore  \
# 0    AK       319            1.0            1.0                   1.0
# 1    AL      4903            1.0            1.0                   0.0
#
#    commercialScore grade  score  negative  pending  ...  death  hospitalized  \
# 0              1.0     A    4.0      9576      NaN  ...    9.0          36.0
# 1              1.0     B    3.0     40875      NaN  ...  160.0         641.0
#
#    total  totalTestResults  posNeg  fips          dateModified  \
# 0   9895              9895    9895     2  2020-04-18T21:45:00Z
# 1  45778             45778   45778     1  2020-04-19T04:00:00Z
#
#             dateChecked                                              notes  \
# 0  2020-04-19T18:11:00Z  Please stop using the "total" field. Use "tota...
# 1  2020-04-20T02:37:00Z  Please stop using the "total" field. Use "tota...
#
#                                        hash
# 0  d2ad361c5b7279d6c8081eb6174b4386cb07aa9c
# 1  e1c29b353b8a905d6fe2adf003a6fa0a468eee7a
#
# [2 rows x 29 columns]

# %% [markdown]
# #### get historical numbers

# %%
df = pd.read_csv(usin)
dfs = pd.read_csv(statesin)

# %%
df.to_csv(usout)
dfs.to_csv(statesout)

# %% [markdown]
# #### brief exploration

# %%
df.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200419      56    749203  3116661.0  11324.0                55490.0
# 1  20200418      56    722182  2976352.0   9906.0                56554.0
# 2  20200417      56    694520  2862973.0  10889.0                57821.0
# 3  20200416      56    663260  2737804.0  16927.0                58353.0
# 4  20200415      56    632656  2610099.0  16901.0                59239.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                 80881.0         14548.0           2145.0
# 1                 78839.0         14788.0           2096.0
# 2                 77955.0         14910.0           2052.0
# 3                 74705.0         15150.0           1834.0
# 4                 69603.0         14667.0           1783.0
#
#    onVentilatorCurrently  ...  death  hospitalized    total totalTestResults  \
# 0                 5603.0  ...  35793       80881.0  3877188          3865864
# 1                 5729.0  ...  34139       78839.0  3708440          3698534
# 2                 6096.0  ...  32365       77955.0  3568382          3557493
# 3                 5940.0  ...  30296       74705.0  3417991          3401064
# 4                 6032.0  ...  28160       69603.0  3259656          3242755
#
#     posNeg  deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0  3865864         1654.0                2042.0          140309.0
# 1  3698534         1774.0                 884.0          113379.0
# 2  3557493         2069.0                3250.0          125169.0
# 3  3401064         2136.0                5102.0          127705.0
# 4  3242755         2492.0                2056.0          130952.0
#
#    positiveIncrease  totalTestResultsIncrease
# 0           27021.0                  167330.0
# 1           27662.0                  141041.0
# 2           31260.0                  156429.0
# 3           30604.0                  158309.0
# 4           30183.0                  161135.0
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#                date     states       positive      negative       pending  \
# count  5.200000e+01  52.000000      52.000000  4.800000e+01     47.000000
# mean   2.020035e+07  48.230769  199324.269231  9.190637e+05  19554.574468
# std    5.170371e+01  16.853016  244762.907321  1.016045e+06  22899.116994
# min    2.020023e+07   1.000000       9.000000  6.000000e+00    103.000000
# 25%    2.020031e+07  51.000000    2105.000000  2.124350e+04   1689.000000
# 50%    2.020032e+07  56.000000   63366.000000  4.882650e+05  14571.000000
# 75%    2.020041e+07  56.000000  371328.250000  1.706225e+06  17369.000000
# max    2.020042e+07  56.000000  749203.000000  3.116661e+06  65709.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count              29.000000               30.000000       25.000000
# mean            31515.413793            38474.400000     8777.160000
# std             20931.548862            26293.839885     5181.255235
# min               112.000000             1964.000000     1299.000000
# 25%             13833.000000            14377.500000     3937.000000
# 50%             29273.000000            38945.000000     9875.000000
# 75%             52235.000000            60538.000000    13917.000000
# max             59239.000000            80881.000000    15150.000000
#
#        inIcuCumulative  onVentilatorCurrently  ...         death  \
# count        26.000000              26.000000  ...     52.000000
# mean        939.692308            3153.461538  ...   7282.961538
# std         704.294357            2637.736397  ...  10805.001498
# min          74.000000             167.000000  ...      4.000000
# 25%         278.750000             520.500000  ...     49.000000
# 50%         851.500000            3518.500000  ...    818.500000
# 75%        1584.750000            5939.250000  ...  11201.500000
# max        2145.000000            6168.000000  ...  35793.000000
#
#        hospitalized         total  totalTestResults        posNeg  \
# count     30.000000  5.200000e+01      5.200000e+01  5.200000e+01
# mean   38474.400000  1.065365e+06      1.047691e+06  1.047691e+06
# std    26293.839885  1.255491e+06      1.250883e+06  1.250883e+06
# min     1964.000000  9.000000e+00      9.000000e+00  9.000000e+00
# 25%    14377.500000  1.030775e+04      9.662250e+03  9.662250e+03
# 50%    38945.000000  4.260880e+05      3.932540e+05  3.932540e+05
# 75%    60538.000000  1.979055e+06      1.961956e+06  1.961956e+06
# max    80881.000000  3.877188e+06      3.865864e+06  3.865864e+06
#
#        deathIncrease  hospitalizedIncrease  negativeIncrease  \
# count      51.000000             51.000000         51.000000
# mean      701.745098           1585.901961      61111.000000
# std       825.037571           1629.775423      53489.305093
# min         1.000000              0.000000          0.000000
# 25%         7.000000              0.000000       2891.500000
# 50%       225.000000           1345.000000      66606.000000
# 75%      1401.500000           2813.500000     108098.000000
# max      2492.000000           5102.000000     195732.000000
#
#        positiveIncrease  totalTestResultsIncrease
# count         51.000000                 51.000000
# mean       14690.078431              75801.078431
# std        13126.894923              66264.188569
# min            9.000000                  9.000000
# 25%          607.500000               3463.000000
# 50%        12284.000000              78890.000000
# 75%        27868.000000             137993.500000
# max        34550.000000             229268.000000
#
# [8 rows x 22 columns]
