# %% [markdown]
# ## Save data to the project and do some exploration if desired

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
usin = 'https://covidtracking.com/api/us/daily.csv'
statesin = 'https://covidtracking.com/api/v1/states/current.csv'

usout = '../data/raw/covidtracking/us_historical.csv'
statesout = '../data/raw/covidtracking/states_historical.csv'

# %% [markdown]
# #### not going to merge in the numbers from the current day, but you can do so if you like

# %%
pd.read_csv('https://covidtracking.com/api/v1/us/current.csv')
# Out:
#    positive  negative  pending  hospitalizedCurrently  hospitalizedCumulative  \
# 0    633775   2627836    16877                  58342                   69980
#
#    inIcuCurrently  inIcuCumulative  onVentilatorCurrently  \
# 0           15137             1890                   6032
#
#    onVentilatorCumulative  recovered  \
# 0                     223      39787
#
#                                        hash lastModified  death  hospitalized  \
# 0  2aa5267d297aed1493ac4ac85efe87e37505bc3b    4/16/2020  28276         69980
#
#      total  totalTestResults   posNeg  \
# 0  3278488           3261611  3261611
#
#                                                notes
# 0  NOTE: "total", "posNeg", "hospitalized" will b...

# %%
pd.read_csv('https://covidtracking.com/api/v1/states/current.csv').head(2)
# Out:
#   state  positive  positiveScore  negativeScore  negativeRegularScore  \
# 0    AK       293            1.0            1.0                   1.0
# 1    AL      4241            1.0            1.0                   0.0
#
#    commercialScore grade  score  negative  pending  ...  death  hospitalized  \
# 0              1.0     A    4.0      8371      NaN  ...    9.0          34.0
# 1              1.0     B    3.0     29964      NaN  ...  123.0         524.0
#
#    total  totalTestResults  posNeg  fips          dateModified  \
# 0   8664              8664    8664     2  2020-04-15T19:15:00Z
# 1  34205             34205   34205     1  2020-04-15T04:00:00Z
#
#             dateChecked                                              notes  \
# 0  2020-04-15T19:33:00Z  Please stop using the "total" field. Use "tota...
# 1  2020-04-16T02:18:00Z  Please stop using the "total" field. Use "tota...
#
#                                        hash
# 0  f6117c474750956dba32708e7d1f8804ca76f839
# 1  226ea2dd3e83f410ace89d725291fb212de36d30
#
# [2 rows x 29 columns]

# %% [markdown]
# #### get historical numbers

# %%
df = pd.read_csv(usin)
dfs = pd.read_csv(statesin)

# %%
df.to_csv(usout)
dfs.to_csv(statesout)

# %% [markdown]
# #### brief exploration

# %%
df.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200415      56    632656  2610099.0  16901.0                58361.0
# 1  20200414      56    602473  2479147.0  16615.0                54215.0
# 2  20200413      56    576774  2358232.0  17159.0                50968.0
# 3  20200412      56    551826  2254066.0  16419.0                51413.0
# 4  20200411      56    522843  2142823.0  16593.0                51409.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                 69603.0         14667.0           1783.0
# 1                 67547.0         14039.0           1715.0
# 2                 62673.0         13632.0           1628.0
# 3                 61201.0         13917.0           1455.0
# 4                 58549.0         13563.0           1228.0
#
#    onVentilatorCurrently  ...  death  hospitalized    total totalTestResults  \
# 0                 6032.0  ...  28160       69603.0  3259656          3242755
# 1                 5975.0  ...  25668       67547.0  3098235          3081620
# 2                 6168.0  ...  23369       62673.0  2952165          2935006
# 3                 5986.0  ...  21919       61201.0  2822311          2805892
# 4                 5978.0  ...  20355       58549.0  2682259          2665666
#
#     posNeg  deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0  3242755         2492.0                2056.0          130952.0
# 1  3081620         2299.0                4874.0          120915.0
# 2  2935006         1450.0                1472.0          104166.0
# 3  2805892         1564.0                2652.0          111243.0
# 4  2665666         1867.0                2207.0          106793.0
#
#    positiveIncrease  totalTestResultsIncrease
# 0           30183.0                  161135.0
# 1           25699.0                  146614.0
# 2           24948.0                  129114.0
# 3           28983.0                  140226.0
# 4           29591.0                  136384.0
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#                date     states       positive      negative       pending  \
# count  4.800000e+01  48.000000      48.000000  4.400000e+01     43.000000
# mean   2.020034e+07  47.583333  156995.083333  7.368470e+05  20233.000000
# std    4.941842e+01  17.396299  202809.302760  8.478558e+05  23833.936796
# min    2.020023e+07   1.000000       9.000000  6.000000e+00    103.000000
# 25%    2.020031e+07  51.000000    1659.000000  1.622975e+04   1461.500000
# 50%    2.020032e+07  56.000000   41728.500000  3.298880e+05  15569.000000
# 75%    2.020040e+07  56.000000  283841.000000  1.368244e+06  17528.500000
# max    2.020042e+07  56.000000  632656.000000  2.610099e+06  65709.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count              25.000000               26.000000       21.000000
# mean            26855.440000            32378.923077     7620.619048
# std             19342.271038            22613.795648     4840.159114
# min                56.000000             1964.000000     1299.000000
# 25%             11872.000000            12093.000000     3487.000000
# 50%             23825.000000            31849.500000     5677.000000
# 75%             46676.000000            51267.500000    12698.000000
# max             58361.000000            69603.000000    14667.000000
#
#        inIcuCumulative  onVentilatorCurrently  ...         death  \
# count        22.000000              22.000000  ...     48.000000
# mean        741.136364            2664.636364  ...   5126.104167
# std         565.120998            2578.551320  ...   8037.535875
# min          74.000000             167.000000  ...      4.000000
# 25%         199.250000             465.000000  ...     41.500000
# 50%         657.000000             654.000000  ...    467.500000
# 75%        1142.000000            5901.250000  ...   7364.250000
# max        1783.000000            6168.000000  ...  28160.000000
#
#        hospitalized         total  totalTestResults        posNeg  \
# count     26.000000  4.800000e+01      4.800000e+01  4.800000e+01
# mean   32378.923077  8.505636e+05      8.324382e+05  8.324382e+05
# std    22613.795648  1.046601e+06      1.039330e+06  1.039330e+06
# min     1964.000000  9.000000e+00      9.000000e+00  9.000000e+00
# 25%    12093.000000  7.731000e+03      7.191500e+03  7.191500e+03
# 50%    31849.500000  2.680680e+05      2.593615e+05  2.593615e+05
# 75%    51267.500000  1.531503e+06      1.481129e+06  1.481129e+06
# max    69603.000000  3.259656e+06      3.242755e+06  3.242755e+06
#
#        deathIncrease  hospitalizedIncrease  negativeIncrease  \
# count      47.000000             47.000000         47.000000
# mean      599.063830           1480.914894      55534.021277
# std       773.267472           1591.126820      51930.347630
# min         1.000000              0.000000          0.000000
# 25%         6.000000              0.000000       2114.500000
# 50%       129.000000            833.000000      45054.000000
# 75%      1170.500000           2604.000000      98690.500000
# max      2492.000000           4874.000000     195732.000000
#
#        positiveIncrease  totalTestResultsIncrease
# count         47.000000                 47.000000
# mean       13460.574468              68994.595745
# std        12935.665632              64509.830849
# min            9.000000                  9.000000
# 25%          428.000000               2542.500000
# 50%        10158.000000              55729.000000
# 75%        25836.500000             125858.500000
# max        34617.000000             229268.000000
#
# [8 rows x 22 columns]
