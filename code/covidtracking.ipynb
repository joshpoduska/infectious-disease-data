# %% [markdown]
# ## Save data to the project and do some exploration if desired

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
usin = 'https://covidtracking.com/api/us/daily.csv'
statesin = 'https://covidtracking.com/api/v1/states/current.csv'

usout = '../data/raw/covidtracking/us_historical.csv'
statesout = '../data/raw/covidtracking/states_historical.csv'

# %% [markdown]
# #### not going to merge in the numbers from the current day, but you can do so if you like

# %%
pd.read_csv('https://covidtracking.com/api/v1/us/current.csv')
# Out:
#    positive  negative  pending  hospitalizedCurrently  hospitalizedCumulative  \
# 0    776215   3250357     4058                  55672                   83303
#
#    inIcuCurrently  inIcuCumulative  onVentilatorCurrently  \
# 0           14752             2246                   5567
#
#    onVentilatorCumulative  recovered  \
# 0                     214      54657
#
#                                        hash lastModified  death  hospitalized  \
# 0  5c3c2440acd10a3080610203c750d6340407d656    4/21/2020  37570         83303
#
#      total  totalTestResults   posNeg  \
# 0  4030630           4026572  4026572
#
#                                                notes
# 0  NOTE: "total", "posNeg", "hospitalized" will b...

# %%
pd.read_csv('https://covidtracking.com/api/v1/states/current.csv').head(2)
# Out:
#   state  positive  positiveScore  negativeScore  negativeRegularScore  \
# 0    AK       321            1.0            1.0                   1.0
# 1    AL      5078            1.0            1.0                   0.0
#
#    commercialScore grade  score  negative  pending  ...  death  hospitalized  \
# 0              1.0     A    4.0      9803      NaN  ...    9.0          36.0
# 1              1.0     B    3.0     40875      NaN  ...  164.0         641.0
#
#    total  totalTestResults  posNeg  fips          dateModified  \
# 0  10124             10124   10124     2  2020-04-20T18:00:00Z
# 1  45953             45953   45953     1  2020-04-20T04:00:00Z
#
#             dateChecked                                              notes  \
# 0  2020-04-20T18:17:00Z  Please stop using the "total" field. Use "tota...
# 1  2020-04-21T03:17:00Z  Please stop using the "total" field. Use "tota...
#
#                                        hash
# 0  e823271b095661adc50e7f229d7492a3df2ea389
# ...

# %% [markdown]
# #### get historical numbers

# %%
df = pd.read_csv(usin)
dfs = pd.read_csv(statesin)

# %%
df.to_csv(usout)
dfs.to_csv(statesout)

# %% [markdown]
# #### brief exploration

# %%
df.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200420      56    772524  3231027.0   4037.0                55509.0
# 1  20200419      56    749203  3116661.0  11324.0                55490.0
# 2  20200418      56    722182  2976352.0   9906.0                56554.0
# 3  20200417      56    694520  2862973.0  10889.0                57821.0
# 4  20200416      56    663260  2737804.0  16927.0                58353.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                 82879.0         14691.0           2193.0
# 1                 80881.0         14548.0           2145.0
# 2                 78839.0         14788.0           2096.0
# 3                 77955.0         14910.0           2052.0
# 4                 74705.0         15150.0           1834.0
#
#    onVentilatorCurrently  ...  death  hospitalized    total totalTestResults  \
# 0                 5567.0  ...  37321       82879.0  4007588          4003551
# ...

# %%
df.describe()
# Out:
#                date     states       positive      negative       pending  \
# count  5.300000e+01  53.000000      53.000000  4.900000e+01     48.000000
# mean   2.020035e+07  48.377358  210139.358491  9.662466e+05  19231.291667
# std    5.217725e+01  16.724264  254864.656614  1.058266e+06  22764.650776
# min    2.020023e+07   1.000000       9.000000  6.000000e+00    103.000000
# 25%    2.020031e+07  51.000000    2221.000000  2.262400e+04   1690.000000
# 50%    2.020032e+07  56.000000   69508.000000  5.342490e+05  14502.000000
# 75%    2.020041e+07  56.000000  394156.000000  1.788277e+06  17336.000000
# max    2.020042e+07  56.000000  772524.000000  3.231027e+06  65709.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count              30.000000               31.000000       26.000000
# mean            32315.200000            39906.806452     9004.615385
# std             21028.826764            27054.129399     5207.372113
# ...
